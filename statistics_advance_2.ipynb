# %% [markdown]
# Q1.What is hypothesis testing in statistics?
#
# ANS:Hypothesis testing in statistics is a method used to make decisions or inferences about a population based on sample data. It involves testing an assumption (called the **null hypothesis**) against an alternative hypothesis using statistical evidence. The goal is to determine whether there's enough evidence to reject the null hypothesis.

# %% [markdown]
# Q2.What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# ANS:The null hypothesis (H₀) is a statement that there is no effect or no difference, and it represents the status quo or default assumption in a hypothesis test.
#
# The alternative hypothesis (H₁ or Ha) is a statement that contradicts the null hypothesis and represents what you aim to prove—usually that a change, effect, or difference exists.

# %% [markdown]
# Q3.> What is the significance level in hypothesis testing, and why is it important8
#
# ANS:The significance level (denoted as α, alpha) in hypothesis testing is the threshold probability used to decide whether to reject the null hypothesis. It represents the maximum acceptable risk of making a Type I error—that is, rejecting the null hypothesis when it is actually true.

# %% [markdown]
# Q4. What does a P-value represent in hypothesis testing?
#
# ANS:A p-value in hypothesis testing represents the probability of obtaining the observed results (or more extreme) if the null hypothesis is true.
#
# In simple terms:
# It measures the evidence against the null hypothesis.
#
# A small p-value (typically ≤ 0.05) means the observed data is unlikely under H₀, so we may reject H₀.
#
# A large p-value (> 0.05) means the data is consistent with H₀, so we fail to reject H₀.

# %% [markdown]
# Q5. How do you interpret the P-value in hypothesis testing?
#
# ANS:✅ Compare it to the significance level (α):
# If p-value ≤ α
# → Reject the null hypothesis (H₀)
# → There is statistically significant evidence to support the alternative hypothesis (H₁).
#
# If p-value > α
# → Fail to reject the null hypothesis (H₀)
# → There is not enough evidence to support the alternative hypothesis.

# %% [markdown]
# Q6.> What are Type 1 and Type 2 errors in hypothesis testing?
#
# ANS:In hypothesis testing, Type I and Type II errors are the two possible incorrect conclusions:
#
# 1. Type I Error (False Positive):
# Definition: Rejecting the null hypothesis (H₀) when it is actually true.
#
# Example: Concluding that a new drug works when it actually doesn't.
#
# Probability: Denoted by α (significance level), usually 0.05.
#
# 2. Type II Error (False Negative):
# Definition: Failing to reject the null hypothesis when the alternative hypothesis (H₁) is actually true.
#
# Example: Concluding that a new drug doesn't work when it actually does.
#
# Probability: Denoted by β.

# %% [markdown]
# Q7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# ANS:The difference between a one-tailed and a two-tailed test lies in the direction of the hypothesis and how the critical region is set:
#
# 🔹 One-Tailed Test:
# Tests for an effect in one specific direction.
#
# Used when you expect the difference to be greater than or less than a certain value.
#
# The entire significance level (α) is placed on one side of the distribution.
#
# Example:
#
# H₀: μ = 50
#
# H₁: μ > 50 (right-tailed)
#
# or H₁: μ < 50 (left-tailed)
#
# 🔹 Two-Tailed Test:
# Tests for an effect in either direction.
#
# Used when you are interested in any difference, not just one-sided.
#
# The significance level (α) is split between both tails of the distribution.
#
# Example:
#
# H₀: μ = 50
#
# H₁: μ ≠ 50 (could be greater or less)

# %% [markdown]
# Q8. What is the Z-test, and when is it used in hypothesis testing?
#
# ANS:A Z-test is a statistical test used to determine whether there is a significant difference between sample and population means (or between two means) when the population variance is known and/or the sample size is large (n ≥ 30).
#
#  When to Use Z-Test:
# Sample size is large (n ≥ 30).
#
# Population standard deviation (σ) is known.
#
# Data is approximately normally distributed.

# %% [markdown]
# Q9.How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# ANS:For a sample mean:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝜇
# μ = population mean
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# 📌 What It Represents:
# The Z-score tells you how many standard deviations the sample mean is away from the population mean.
#
# It helps determine the position of the sample in the normal distribution.

# %% [markdown]
# Q10.What is the T-distribution, and when should it be used instead of the normal distribution?
#
# ANS: The t-distribution is a probability distribution used in statistics when estimating population parameters with a small sample size and/or unknown population standard deviation.
#
# 🕒 When to Use T-Distribution (Instead of Normal Distribution):
# Sample size is small (n < 30).
#
# Population standard deviation (σ) is unknown.
#
# Data is approximately normally distributed.

# %% [markdown]
# Q11. What is the difference between a Z-test and a T-test8?
#
# ANS: A Z-test and a T-test are both statistical methods used to test hypotheses about population means, but they differ based on sample size and the availability of population standard deviation. A Z-test is used when the sample size is large (typically n ≥ 30) and the population standard deviation (σ) is known. It relies on the normal distribution and is ideal for precise and stable estimates. In contrast, a T-test is used when the sample size is small (n < 30) and the population standard deviation is unknown. It uses the t-distribution, which has thicker tails to account for the increased uncertainty in small samples. As the sample size increases, the t-distribution approaches the normal distribution.

# %% [markdown]
# Q12.> What is the T-test, and how is it used in hypothesis testing?
#
# ANS:The T-test is a statistical test used to determine whether there is a significant difference between means when the population standard deviation is unknown and/or the sample size is small. It is based on the t-distribution, which adjusts for the extra uncertainty due to estimating the standard deviation from the sample.
#
# In hypothesis testing, the T-test is used to compare:
#
# A sample mean to a known value (one-sample t-test),
#
# The means of two independent groups (independent two-sample t-test), or
#
# The means of paired or related samples (paired t-test).
#
# The test involves calculating a t-score using the sample data, then comparing it to a critical value from the t-distribution table at a chosen significance level (α). If the t-score falls in the critical region, we reject the null hypothesis, suggesting a significant difference exists.

# %% [markdown]
# Q13.What is the relationship between Z-test and T-test in hypothesis testing?
#
# ANS:The Z-test and T-test are both statistical methods used in hypothesis testing to determine whether there is a significant difference between sample statistics and population parameters (usually means). They are closely related and serve similar purposes, but are used under different conditions.
#
# ✅ Relationship:
# Purpose:
# Both tests compare means and help decide whether to reject the null hypothesis.
#
# Core Formula Structure:
# Both use a test statistic calculated as:
#
# Test statistic
# =
# 𝑋
# ˉ
# −
# 𝜇
# Standard Error
# Test statistic=
# Standard Error
# X
# ˉ
#  −μ
# ​
#
# The difference lies in how the standard error is calculated and which distribution (Z or t) is used.
#
# Distribution Used:
#
# Z-test uses the standard normal distribution.
#
# T-test uses the t-distribution, which is similar to the normal distribution but has fatter tails to account for more variability in small samples.

# %% [markdown]
# Q14.What is a confidence interval, and how is it used to interpret statistical results?
#
# ANS:A confidence interval gives a range within which we believe the true population value lies, along with an associated confidence level (commonly 90%, 95%, or 99%).
#
# * How It’s Used:
# It helps assess how precise the sample estimate is.
#
# A wider interval suggests more uncertainty; a narrower interval suggests more precision.
#
# If a confidence interval for a mean difference includes 0, it suggests no significant difference.

# %% [markdown]
# Q15.What is the margin of error, and how does it affect the confidence interval?
#
# ANS:The margin of error is the amount added and subtracted from the sample estimate to create a confidence interval. It reflects the maximum expected difference between the sample statistic and the true population parameter.
#
# It Affects the Confidence Interval BY:
#
# A larger margin of error results in a wider confidence interval, meaning less precision.
#
# A smaller margin of error gives a narrower interval, meaning more precise estimation.

# %% [markdown]
# Q16.How is Bayes' Theorem used in statistics, and what is its significance?
#
# ANS: Bayes' Theorem in Statistics:
# Bayes' Theorem is a mathematical formula used to update the probability of a hypothesis based on new evidence or information. It combines prior knowledge with new data to calculate a posterior probability.
#
# 📌 Formula:
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) = Posterior probability (probability of A given B)
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) = Likelihood (probability of B given A)
#
# 𝑃
# (
# 𝐴
# )
# P(A) = Prior probability of A
#
# 𝑃
# (
# 𝐵
# )
# P(B) = Total probability of B
#
# * Significance:
# Revises beliefs with new data (used in medical testing, spam filters, machine learning, etc.).
#
# Helps in decision-making under uncertainty.
#
# Forms the foundation of Bayesian statistics, which treats unknown parameters as random variables.

# %% [markdown]
# Q17.What is the Chi-square distribution, and when is it used?
#
# ANS:The Chi-square (χ²) distribution is a skewed, non-negative probability distribution used in statistics, especially when dealing with categorical data.
#
# 📌 When It’s Used:
# Goodness-of-Fit Test
# → To check if observed data fits an expected distribution.
#
# Test of Independence
# → To examine if two categorical variables are independent in a contingency table.
#
# Test for Variance
# → To test hypotheses about population variance when the population is normally distributed.

# %% [markdown]
# Q18.What is the Chi-square goodness of fit test, and how is it applied?
#
# ANS:The Chi-square goodness of fit test is a statistical method used to determine whether the observed frequencies in a categorical dataset match the expected frequencies based on a specific theoretical distribution.
#
# Steps to Apply:
# State hypotheses:
#
# H₀: Observed data follows the expected distribution
#
# H₁: Observed data does not follow the expected distribution
#
# Calculate expected frequencies under the assumed distribution.
#
# Compute the Chi-square statistic using the formula.
#
# Determine degrees of freedom:
#
# df
# =
# number of categories
# −
# 1
# df=number of categories−1
# Compare the test statistic with the critical value from the Chi-square distribution table, or calculate the p-value.
#
# Make a decision:
#
# If
# 𝜒
# 2
# χ
# 2
#   > critical value or p-value < α → Reject H₀
#
# Otherwise → Fail to reject H₀

# %% [markdown]
# Q19.What is the F-distribution, and when is it used in hypothesis testing?
#
# ANS:The F-distribution is a right-skewed, continuous probability distribution that arises when comparing two variances. It is used primarily in hypothesis testing for variance analysis.
#
# * When It’s Used:
# ANOVA (Analysis of Variance):
#
# To compare the means of three or more groups by analyzing variation between and within groups.
#
# Checks if at least one group mean is significantly different.
#
# Test for Equality of Variances:
#
# Compares whether two population variances are equal (e.g., in the F-test for variance).

# %% [markdown]
# Q20.What is an ANOVA test, and what are its assumptions?
#
# ANS:ANOVA is a statistical method used to compare the means of three or more groups to determine if at least one group mean is significantly different from the others.
#
# It uses the F-distribution to test the null hypothesis that all group means are equal.
#
# Key Assumptions of ANOVA:
# Independence:
# Observations must be independent within and across groups.
#
# Normality:
# Data in each group should be approximately normally distributed.
#
# Homogeneity of Variance (Homoscedasticity):
# All groups should have equal variances.

# %% [markdown]
# Q21. What are the different types of ANOVA tests?
#
# ANS:There are three main types of ANOVA tests, each suited for different experimental designs and data structures:
#
# 1. One-Way ANOVA
# Purpose: Compares the means of three or more independent groups based on one factor (independent variable).
#
# Example: Comparing test scores of students from three different teaching methods.
#
# Assumptions: Normality, independence, equal variances.
#
# 2. Two-Way ANOVA
# Purpose: Compares the means across groups that vary in two factors and also checks for interaction effects between them.
#
# Example: Examining how teaching method and gender affect student scores.
#
# Output: Main effect of factor A, main effect of factor B, and interaction effect (A × B).
#
# 3. Repeated Measures ANOVA
# Purpose: Used when the same subjects are measured multiple times under different conditions or over time.

# %% [markdown]
# ***PRACTICAL QUESTIONS PART 1***

# %% [markdown]
# Q1.Write a Python program to generate a random variable and display its value?

# %%
import random

# Generate a random variable from a uniform distribution (0 to 1)
random_variable = random.random()

print("Generated Random Variable:", random_variable)
# Out:
# Generated Random Variable: 0.8437382978835234

# %% [markdown]
# Q2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range for the discrete uniform distribution
low = 1   # inclusive lower bound
high = 7  # exclusive upper bound (for values 1 to 6, like a die)

# Generate x values (possible outcomes)
x = np.arange(low, high)

# Create a discrete uniform distribution
dist = randint(low, high)

# Get PMF values
pmf_values = dist.pmf(x)

plt.stem(x, pmf_values, basefmt=" ")
plt.xlabel('Value')
plt.ylabel('PMF')
plt.title('PMF of Discrete Uniform Distribution (Die Roll)')
plt.xticks(x)
plt.grid(True)
plt.show()

# %% [markdown]
# Q3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution>

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the PDF of a Bernoulli distribution.

    Parameters:
    x (int): Outcome (0 or 1)
    p (float): Probability of success (0 ≤ p ≤ 1)

    Returns:
    float: Probability of observing x
    """
    if x not in [0, 1]:
        return 0.0  # Bernoulli outcomes are only 0 or 1
    return p**x * (1 - p)**(1 - x)

# %% [markdown]
# Q4.> Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10          # Number of trials
p = 0.5         # Probability of success
size = 1000     # Number of simulations

# Simulate binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=np.arange(0, n+2)-0.5, edgecolor='black', density=True)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xticks(range(n+1))
plt.grid(True)
plt.show()

# %% [markdown]
# Q5. Create a Poisson distribution and visualize it using Python?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameter (mean rate of occurrence)
lambda_val = 4

# Range of x values (0 to 15)
x = np.arange(0, 16)

# Compute PMF values
pmf_values = poisson.pmf(x, mu=lambda_val)

# Plot the PMF
plt.stem(x, pmf_values, basefmt=" ")
plt.xlabel('Number of Events (x)')
plt.ylabel('PMF')
plt.title(f'Poisson Distribution (λ = {lambda_val})')
plt.xticks(x)
plt.grid(True)
plt.show()

# %% [markdown]
# Q6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range for the discrete uniform distribution (e.g., a fair die)
low = 1
high = 7  # upper bound is exclusive, so values will be 1 through 6

# Create the distribution object
dist = randint(low, high)

# Generate x values (possible outcomes)
x = np.arange(low, high)

# Calculate CDF values
cdf_values = dist.cdf(x)

# Plot the CDF
plt.step(x, cdf_values, where='post', label='CDF')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xticks(x)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Q7.> Generate a continuous uniform distribution using NumPy and visualize it?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Parameters for the continuous uniform distribution
a = 0      # lower bound
b = 10     # upper bound
size = 1000  # number of samples

# Generate random samples from a continuous uniform distribution
samples = np.random.uniform(a, b, size)

# Plot histogram of the samples
plt.hist(samples, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Histogram')

# Plot the theoretical PDF
x = np.linspace(a, b, 1000)
pdf = uniform.pdf(x, loc=a, scale=b - a)
plt.plot(x, pdf, 'r-', lw=2, label='PDF (Uniform)')

# Add labels and title
plt.title('Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Q8.Simulate data from a normal distribution and plot its histogram?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mean = 0      # Mean (μ)
std_dev = 1   # Standard deviation (σ)
size = 1000   # Number of samples

# Generate random samples from a normal distribution
samples = np.random.normal(loc=mean, scale=std_dev, size=size)

# Plot histogram of the samples
plt.hist(samples, bins=30, density=True, color='lightblue', edgecolor='black')
plt.title('Histogram of Simulated Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# %% [markdown]
# Q9. Write a Python function to calculate Z-scores from a dataset and plot them?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

def calculate_and_plot_zscores(data):
    """
    Calculates Z-scores for a dataset and plots a histogram.

    Parameters:
    data (list or np.ndarray): The dataset to calculate Z-scores for.
    """
    # Convert data to NumPy array for easier calculation
    data = np.asarray(data)

    # Calculate Z-scores
    # Using scipy.stats.zscore is a convenient way
    z_scores = zscore(data)

    # Plotting the histogram of Z-scores
    plt.figure(figsize=(8, 6))
    plt.hist(z_scores, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')
    plt.title('Histogram of Z-Scores')
    plt.xlabel('Z-Score')
    plt.ylabel('Density')
    plt.grid(True)
    plt.show()

    print("\nExample Z-scores:")
    print(z_scores[:10]) # Print first 10 z-scores as an example

# Example Usage:
# Create a sample dataset
sample_data = [1, 2, 2, 3, 3, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 10, 11, 12, 13, 14, 15]

# Calculate and plot Z-scores for the sample data
calculate_and_plot_zscores(sample_data)

# Example with a normal distribution
# normal_data = np.random.normal(loc=50, scale=10, size=200)
# calculate_and_plot_zscores(normal_data)
# Out:
# Example Z-scores:
# [-1.45248373 -1.21418562 -1.21418562 -0.97588751 -0.97588751 -0.97588751
#  -0.73758939 -0.73758939 -0.49929128 -0.26099317]

# %% [markdown]
# Q10.> Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Parameters
population_size = 100000
sample_size = 30       # Size of each sample
num_samples = 1000     # Number of samples

# Generate a non-normal population (exponential distribution)
population = np.random.exponential(scale=2.0, size=population_size)

# Collect sample means
sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Plot the original (non-normal) population distribution
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='orange', edgecolor='black', density=True)
plt.title('Original Non-Normal Population\n(Exponential Distribution)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)

# Plot the sampling distribution of the sample mean
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=30, color='skyblue', edgecolor='black', density=True)
plt.title(f'Sampling Distribution of Sample Means\n(n = {sample_size}, samples = {num_samples})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Q11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(0)

# Parameters
population_mean = 50
population_std = 10
sample_size = 30
num_samples = 1000

# Generate multiple samples and compute their means
sample_means = []

for _ in range(num_samples):
    sample = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

# Plot histogram of the sample means
plt.hist(sample_means, bins=30, color='lightgreen', edgecolor='black', density=True)
plt.title(f'Sampling Distribution of the Mean\n({num_samples} samples of size {sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# Q12.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Plots the Standard Normal Distribution (mean = 0, std = 1).
    """
    # Generate values
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, loc=0, scale=1)  # Standard normal PDF

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal PDF', color='blue')
    plt.title('Standard Normal Distribution (μ = 0, σ = 1)')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.axvline(0, color='black', linestyle='--', linewidth=1)
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# Q13.Generate random variables and calculate their corresponding probabilities using the binomial distribution?

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Parameters
n = 10        # number of trials
p = 0.5       # probability of success
size = 1000   # number of random samples

# Generate random variables (number of successes)
samples = np.random.binomial(n=n, p=p, size=size)

# Unique outcomes and their frequencies
values, counts = np.unique(samples, return_counts=True)
probs = binom.pmf(values, n, p)  # Theoretical probabilities

# Plot empirical and theoretical probabilities
plt.figure(figsize=(8, 5))
plt.bar(values, counts / size, width=0.6, label='Empirical Probability', alpha=0.6, color='skyblue', edgecolor='black')
plt.plot(values, probs, 'o-', label='Theoretical PMF (Binomial)', color='red')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Q14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std):
    """
    Calculate Z-score for a given data point.
    """
    return (x - mean) / std

# Example data
data_point = 72
population_mean = 70
population_std = 5

# Calculate Z-score
z = calculate_z_score(data_point, population_mean, population_std)
print(f"Z-score of {data_point} is: {z:.2f}")

# Plot standard normal distribution
x_vals = np.linspace(-4, 4, 1000)
y_vals = norm.pdf(x_vals, 0, 1)

plt.figure(figsize=(8, 5))
plt.plot(x_vals, y_vals, label='Standard Normal Distribution', color='blue')
plt.fill_between(x_vals, y_vals, where=(x_vals <= z), color='lightgreen', alpha=0.6, label=f'Z ≤ {z:.2f}')
plt.axvline(z, color='red', linestyle='--', label=f'Z-score = {z:.2f}')
plt.title('Z-score Comparison with Standard Normal Distribution')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-score of 72 is: 0.40

# %% [markdown]
# Q15. Implement hypothesis testing using Z-statistics for a sample dataset?

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = np.array([68, 72, 70, 69, 73, 71, 74, 68, 70, 69])
sample_mean = np.mean(sample)
sample_size = len(sample)
sample_std = np.std(sample, ddof=1)  # Sample standard deviation

# Known population mean (H0: mu = 70)
population_mean = 70
alpha = 0.05  # Significance level

# Z-statistic calculation
standard_error = sample_std / np.sqrt(sample_size)
z_score = (sample_mean - population_mean) / standard_error

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.4f}")

# Decision
if p_value < alpha:
    print("Reject the null hypothesis (H0)")
else:
    print("Fail to reject the null hypothesis (H0)")
# Out:
# Sample Mean: 70.40
# Z-score: 0.61
# P-value: 0.5403
# Fail to reject the null hypothesis (H0)

# %% [markdown]
# Q16. Create a confidence interval for a dataset using Python and interpret the result?

# %%
import numpy as np
from scipy.stats import t

# Sample data
data = np.array([52, 55, 48, 50, 53, 49, 54, 51, 56, 47])

# Sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
n = len(data)
confidence = 0.95
alpha = 1 - confidence

# t critical value for two-tailed test
t_critical = t.ppf(1 - alpha/2, df=n-1)

# Margin of error
margin_of_error = t_critical * (sample_std / np.sqrt(n))

# Confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 51.50
# 95% Confidence Interval: (49.33, 53.67)

# %% [markdown]
# Q17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean?

# %%
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt

# Step 1: Generate data from a normal distribution
np.random.seed(0)  # For reproducibility
data = np.random.normal(loc=100, scale=15, size=50)  # mean=100, std=15, n=50

# Step 2: Calculate sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
n = len(data)
confidence = 0.95
alpha = 1 - confidence

# Step 3: Compute t-critical value and margin of error
t_critical = t.ppf(1 - alpha/2, df=n-1)
margin_of_error = t_critical * (sample_std / np.sqrt(n))

# Step 4: Confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

plt.hist(data, bins=10, color='lightblue', edgecolor='black', alpha=0.7)
plt.axvline(sample_mean, color='red', linestyle='--', label='Sample Mean')
plt.axvline(ci_lower, color='green', linestyle='--', label='95% CI Lower')
plt.axvline(ci_upper, color='green', linestyle='--', label='95% CI Upper')
plt.title('Histogram of Simulated Normal Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Sample Mean: 102.11
# 95% Confidence Interval: (97.26, 106.96)

# %% [markdown]
# Q18.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 0      # Mean (μ)
std_dev = 1   # Standard deviation (σ)

# Generate x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Calculate PDF values
pdf_values = norm.pdf(x, loc=mean, scale=std_dev)

# Plotting the PDF
plt.figure(figsize=(8, 4))
plt.plot(x, pdf_values, color='blue', lw=2, label='Normal PDF')
plt.title('Probability Density Function of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Q19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_param = 4  # Average rate (λ)
x_values = np.arange(0, 15)

# Calculate the CDF
cdf_values = poisson.cdf(x_values, mu=lambda_param)

# Print CDF values
for x, cdf in zip(x_values, cdf_values):
    print(f"P(X ≤ {x}) = {cdf:.4f}")

# Plotting the CDF
plt.step(x_values, cdf_values, where='post', color='purple', label='Poisson CDF')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# Q20.Simulate a random variable using a continuous uniform distribution and calculate its expected value?

# %%
import numpy as np

# Parameters for the continuous uniform distribution
a = 10   # Lower bound
b = 30   # Upper bound
n = 10000  # Number of samples

# Simulate random variables
samples = np.random.uniform(low=a, high=b, size=n)

# Calculate expected value from simulation
expected_value_simulated = np.mean(samples)

# Theoretical expected value for Uniform(a, b)
expected_value_theoretical = (a + b) / 2

# Print the results
print(f"Theoretical Expected Value: {expected_value_theoretical}")
print(f"Simulated Expected Value: {expected_value_simulated:.4f}")
# Out:
# Theoretical Expected Value: 20.0
# Simulated Expected Value: 19.9283

# %% [markdown]
# Q21.Write a Python program to compare the standard deviations of two datasets and visualize the difference?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
np.random.seed(42)  # Reproducibility

# Dataset 1: Smaller spread
data1 = np.random.normal(loc=50, scale=5, size=1000)

# Dataset 2: Larger spread
data2 = np.random.normal(loc=50, scale=15, size=1000)

# Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

# Print results
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Plot histograms
plt.figure(figsize=(10, 5))
plt.hist(data1, bins=30, alpha=0.6, label='Dataset 1 (σ ≈ 5)', color='blue')
plt.hist(data2, bins=30, alpha=0.6, label='Dataset 2 (σ ≈ 15)', color='orange')
plt.axvline(np.mean(data1), color='blue', linestyle='dashed', linewidth=1.5)
plt.axvline(np.mean(data2), color='orange', linestyle='dashed', linewidth=1.5)
plt.title('Comparison of Standard Deviations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 14.96

# %% [markdown]
# Q22.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution?

# %%
import numpy as np
import scipy.stats as stats

# Generate dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=100, scale=15, size=1000)

# Calculate range
data_range = np.max(data) - np.min(data)

# Calculate IQR (Q3 - Q1)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Print results
print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
print(f"Q1 (25th percentile): {q1:.2f}")
print(f"Q3 (75th percentile): {q3:.2f}")
# Out:
# Range: 106.41
# Interquartile Range (IQR): 19.43
# Q1 (25th percentile): 90.29
# Q3 (75th percentile): 109.72

# %% [markdown]
# Q23.E Implement Z-score normalization on a dataset and visualize its transformation

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a sample dataset (normal distribution with arbitrary mean and std)
np.random.seed(42)
data = np.random.normal(loc=70, scale=10, size=1000)  # Mean=70, SD=10

# Z-score normalization: (x - mean) / std
mean_original = np.mean(data)
std_original = np.std(data)
z_scores = (data - mean_original) / std_original

# Verify transformation
mean_z = np.mean(z_scores)
std_z = np.std(z_scores)

# Print results
print(f"Original Mean: {mean_original:.2f}, Original Std Dev: {std_original:.2f}")
print(f"Z-score Mean: {mean_z:.2f}, Z-score Std Dev: {std_z:.2f}")

# Plot original and normalized data
plt.figure(figsize=(12, 5))

# Original data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)

# Normalized data (Z-scores)
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, color='lightgreen', edgecolor='black')
plt.title('Z-Score Normalized Distribution')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 70.19, Original Std Dev: 9.79
# Z-score Mean: -0.00, Z-score Std Dev: 1.00

# %% [markdown]
# Q24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_distribution_stats(mean=0, std=1, size=1000):
    # Generate data from normal distribution
    data = np.random.normal(loc=mean, scale=std, size=size)

    # Calculate skewness and kurtosis
    skewness = skew(data)
    excess_kurtosis = kurtosis(data)  # By default, gives excess kurtosis (normal = 0)

    # Print results
    print(f"Skewness: {skewness:.4f}")
    print(f"Excess Kurtosis: {excess_kurtosis:.4f}")

    return skewness, excess_kurtosis

# Example usage
analyze_distribution_stats(mean=100, std=15, size=1000)
# Out:
# Skewness: -0.0493
# Excess Kurtosis: 0.0521
# (np.float64(-0.04932177396530076), np.float64(0.05211754569783933))

# %% [markdown]
# ***Practical Questions 2***

# %% [markdown]
# Q1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results?

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):
    # Sample statistics
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Calculate Z-statistic
    z = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Calculate two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z)))

    # Output results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-statistic: {z:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpret the result
    if p_value < alpha:
        print("Reject the null hypothesis: Sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference from the population mean.")

# Example usage
np.random.seed(42)
sample = np.random.normal(loc=102, scale=15, size=50)  # Simulated sample data

# Perform Z-test
z_test(sample_data=sample, population_mean=100, population_std=15)
# Out:
# Sample Mean: 98.6179
# Z-statistic: -0.6515
# P-value: 0.5147
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# Q2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python?

# %%
import numpy as np
from scipy.stats import norm

def perform_hypothesis_test(pop_mean, pop_std, sample_size=50, alpha=0.05):
    # Step 1: Simulate random sample data from a normal distribution
    np.random.seed(0)
    sample_data = np.random.normal(loc=pop_mean + 2, scale=pop_std, size=sample_size)  # Simulated with shifted mean

    # Step 2: Calculate sample mean
    sample_mean = np.mean(sample_data)

    # Step 3: Compute Z-statistic
    z = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))

    # Step 4: Calculate two-tailed P-value
    p_value = 2 * (1 - norm.cdf(abs(z)))

    # Step 5: Print the result
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-Statistic: {z:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Step 6: Interpret the result
    if p_value < alpha:
        print("Result: Reject the null hypothesis (significant difference).")
    else:
        print("Result: Fail to reject the null hypothesis (no significant difference).")

# Example usage
perform_hypothesis_test(pop_mean=100, pop_std=15, sample_size=50)
# Out:
# Sample Mean: 104.1084
# Z-Statistic: 1.9367
# P-value: 0.0528
# Result: Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# Q3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean?

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05):
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    # Calculate Z-statistic
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Calculate two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_score)))

    # Display results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Hypothesis decision
    if p_value < alpha:
        print("Reject the null hypothesis: Sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference from the population mean.")

# Example: Generate sample data
np.random.seed(1)
sample_data = np.random.normal(loc=102, scale=15, size=40)

# Perform one-sample Z-test
one_sample_z_test(sample_data, population_mean=100, population_std=15)
# Out:
# Sample Mean: 100.6560
# Z-score: 0.2766
# P-value: 0.7821
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# Q4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def two_tailed_z_test_with_plot(sample_data, population_mean, population_std, alpha=0.05):
    """
    Performs a two-tailed Z-test and visualizes the decision region.

    Parameters:
    sample_data (array-like): The sample data.
    population_mean (float): The hypothesized population mean under the null hypothesis.
    population_std (float): The known population standard deviation.
    alpha (float): The significance level (default is 0.05).
    """
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Calculate Z-statistic
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Calculate two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_score)))

    # Calculate critical Z-values for a two-tailed test
    z_critical_lower = norm.ppf(alpha / 2)
    z_critical_upper = norm.ppf(1 - alpha / 2)

    # Display results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")
    print(f"Critical Z-values (alpha={alpha}): ({z_critical_lower:.4f}, {z_critical_upper:.4f})")

    # Hypothesis decision
    if abs(z_score) > z_critical_upper: # or p_value < alpha
        print("Reject the null hypothesis: Sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference from the population mean.")

    # --- Visualization ---
    plt.figure(figsize=(10, 6))
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, 0, 1)  # Standard normal distribution

    plt.plot(x, y, label='Standard Normal Distribution', color='blue')

    # Shade the rejection regions
    x_reject_lower = np.linspace(-4, z_critical_lower, 100)
    y_reject_lower = norm.pdf(x_reject_lower, 0, 1)
    plt.fill_between(x_reject_lower, y_reject_lower, color='red', alpha=0.3, label=f'Rejection Region (α/2 = {alpha/2:.2f})')

    x_reject_upper = np.linspace(z_critical_upper, 4, 100)
    y_reject_upper = norm.pdf(x_reject_upper, 0, 1)
    plt.fill_between(x_reject_upper, y_reject_upper, color='red', alpha=0.3)

    # Plot the calculated Z-score
    plt.axvline(z_score, color='green', linestyle='--', label=f'Observed Z-score = {z_score:.2f}')

    # Plot critical values
    plt.axvline(z_critical_lower, color='black', linestyle=':', label=f'Critical Z ({alpha/2:.2f}) = {z_critical_lower:.2f}')
    plt.axvline(z_critical_upper, color='black', linestyle=':', label=f'Critical Z (1-α/2 = {1-alpha/2:.2f}) = {z_critical_upper:.2f}')


    plt.title('Two-Tailed Z-Test Visualization')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example Usage:
np.random.seed(2) # for reproducibility
# Simulate sample data (e.g., testing if the mean differs from 100)
sample_data = np.random.normal(loc=103, scale=15, size=50)

# Perform the two-tailed Z-test and visualize
two_tailed_z_test_with_plot(sample_data, population_mean=100, population_std=15, alpha=0.05)
# Out:
# Sample Mean: 100.9038
# Z-score: 0.4261
# P-value: 0.6701
# Critical Z-values (alpha=0.05): (-1.9600, 1.9600)
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# Q5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testingE

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu0=100, mu1=105, sigma=10, n=30, alpha=0.05):
    # Standard error
    se = sigma / np.sqrt(n)

    # Critical value for right-tailed test
    z_crit = norm.ppf(1 - alpha)

    # Critical sample mean under H0
    x_crit = mu0 + z_crit * se

    # Type II error: area under H1 to the left of critical value
    beta = norm.cdf((x_crit - mu1) / se)

    # X range for plotting
    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)

    # Distributions under H0 and H1
    y0 = norm.pdf(x, mu0, se)
    y1 = norm.pdf(x, mu1, se)

    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(x, y0, label='H0: μ = {:.1f}'.format(mu0), color='blue')
    plt.plot(x, y1, label='H1: μ = {:.1f}'.format(mu1), color='green')

    # Fill Type I error (alpha)
    plt.fill_between(x, y0, where=(x > x_crit), color='red', alpha=0.4, label='Type I Error (α)')

    # Fill Type II error (beta)
    plt.fill_between(x, y1, where=(x < x_crit), color='orange', alpha=0.4, label='Type II Error (β)')

    # Annotations
    plt.axvline(x_crit, color='black', linestyle='--', label='Critical Value')

    plt.title("Type I and Type II Error Visualization")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print results
    print(f"Critical Value (x̄): {x_crit:.2f}")
    print(f"Type I Error (α): {alpha}")
    print(f"Type II Error (β): {beta:.4f}")
    print(f"Power of the test (1 - β): {1 - beta:.4f}")

# Example usage
visualize_type1_type2_errors(mu0=100, mu1=105, sigma=10, n=30, alpha=0.05)
# Out:
# Critical Value (x̄): 103.00
# Type I Error (α): 0.05
# Type II Error (β): 0.1370
# Power of the test (1 - β): 0.8630

# %% [markdown]
# Q6.Write a Python program to perform an independent T-test and interpret the results?

# %%
import numpy as np
from scipy.stats import ttest_ind

# Sample data: Two independent groups
group1 = np.random.normal(loc=100, scale=10, size=30)  # Mean ~100
group2 = np.random.normal(loc=105, scale=12, size=30)  # Mean ~105

# Perform independent t-test (assuming equal variance)
t_stat, p_value = ttest_ind(group1, group2, equal_var=True)

# Print results
print("Group 1 Mean:", np.mean(group1))
print("Group 2 Mean:", np.mean(group2))
print("T-statistic:", round(t_stat, 4))
print("P-value:", round(p_value, 4))

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("✅ Reject the null hypothesis: The means of the two groups are significantly different.")
else:
    print("❌ Fail to reject the null hypothesis: No significant difference between the two group means.")
# Out:
# Group 1 Mean: 97.75536287359705
# Group 2 Mean: 107.97964720999605
# T-statistic: -3.3872
# P-value: 0.0013
# ✅ Reject the null hypothesis: The means of the two groups are significantly different.

# %% [markdown]
# Q7.Perform a paired sample T-test using Python and visualize the comparison results?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Simulate paired sample data (e.g., before and after intervention)
np.random.seed(42)
before = np.random.normal(loc=100, scale=10, size=30)
after = before + np.random.normal(loc=-2, scale=5, size=30)  # slight improvement

# Perform paired t-test
t_stat, p_value = ttest_rel(before, after)

# Print test results
print(f"Mean Before: {np.mean(before):.2f}")
print(f"Mean After: {np.mean(after):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("✅ Reject the null hypothesis: Significant difference between before and after.")
else:
    print("❌ Fail to reject the null hypothesis: No significant difference.")

# Visualization
plt.figure(figsize=(10, 5))
x = np.arange(len(before))
plt.plot(x, before, marker='o', label='Before', linestyle='--', color='blue')
plt.plot(x, after, marker='s', label='After', linestyle='--', color='green')
for i in range(len(before)):
    plt.plot([x[i], x[i]], [before[i], after[i]], color='gray', linestyle=':', alpha=0.6)  # line between pairs
plt.title('Paired Sample Comparison (Before vs After)')
plt.xlabel('Subject Index')
plt.ylabel('Scores')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Mean Before: 98.12
# Mean After: 95.51
# T-statistic: 3.0657
# P-value: 0.0047
# ✅ Reject the null hypothesis: Significant difference between before and after.

# %% [markdown]
# Q8. Simulate data and perform both Z-test and T-test, then compare the results using Python?

# %%
import numpy as np
from scipy.stats import ttest_1samp, norm
import matplotlib.pyplot as plt

# Parameters
np.random.seed(42)
population_mean = 100
sample_size = 30
sample = np.random.normal(loc=98, scale=10, size=sample_size)
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)  # sample standard deviation

# Z-test (when population standard deviation is known)
pop_std = 10  # known population standard deviation
z_score = (sample_mean - population_mean) / (pop_std / np.sqrt(sample_size))
p_value_z = 2 * (1 - norm.cdf(abs(z_score)))

# T-test (when population std is unknown)
t_stat, p_value_t = ttest_1samp(sample, population_mean)

# Display Results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Std Dev: {sample_std:.2f}")
print("\n--- Z-Test Results ---")
print(f"Z-Score: {z_score:.4f}")
print(f"P-Value (Z-test): {p_value_z:.4f}")

print("\n--- T-Test Results ---")
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value (T-test): {p_value_t:.4f}")

# Decision
alpha = 0.05
print("\n--- Interpretation ---")
if p_value_z < alpha:
    print("Z-test: ✅ Reject the null hypothesis.")
else:
    print("Z-test: ❌ Fail to reject the null hypothesis.")

if p_value_t < alpha:
    print("T-test: ✅ Reject the null hypothesis.")
else:
    print("T-test: ❌ Fail to reject the null hypothesis.")

# Optional: Visualization
plt.hist(sample, bins=10, alpha=0.6, color='skyblue', edgecolor='black')
plt.axvline(population_mean, color='red', linestyle='dashed', label='Population Mean')
plt.axvline(sample_mean, color='green', linestyle='dashed', label='Sample Mean')
plt.title("Sample Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Sample Mean: 96.12
# Sample Std Dev: 9.00
#
# --- Z-Test Results ---
# Z-Score: -2.1260
# P-Value (Z-test): 0.0335
#
# --- T-Test Results ---
# T-Statistic: -2.3622
# P-Value (T-test): 0.0251
#
# --- Interpretation ---
# Z-test: ✅ Reject the null hypothesis.
# T-test: ✅ Reject the null hypothesis.

# %% [markdown]
# Q9.E Write a Python function to calculate the confidence interval for a sample mean and explain its significance?

# %%
import numpy as np
from scipy import stats

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for the sample mean.

    Parameters:
    - sample (array-like): Sample data
    - confidence (float): Confidence level (default 0.95 for 95%)

    Returns:
    - Tuple (lower bound, upper bound)
    """
    n = len(sample)
    mean = np.mean(sample)
    std_err = stats.sem(sample)  # standard error of the mean
    margin = std_err * stats.t.ppf((1 + confidence) / 2, df=n-1)

    return mean - margin, mean + margin

# Example usage
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=30)
ci_low, ci_high = confidence_interval(data, confidence=0.95)

print(f"Sample Mean: {np.mean(data):.2f}")
print(f"95% Confidence Interval: ({ci_low:.2f}, {ci_high:.2f})")
# Out:
# Sample Mean: 48.12
# 95% Confidence Interval: (44.76, 51.48)

# %% [markdown]
# Q10. Write a Python program to calculate the margin of error for a given confidence level using sample data?

# %%
import numpy as np
from scipy import stats

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for a sample mean.

    Parameters:
    - sample (array-like): The sample data
    - confidence (float): The confidence level (default = 0.95)

    Returns:
    - margin of error (float)
    """
    n = len(sample)
    std_err = stats.sem(sample)  # standard error of the mean
    t_score = stats.t.ppf((1 + confidence) / 2, df=n-1)  # critical t-score
    return t_score * std_err

# Example usage
np.random.seed(0)
sample_data = np.random.normal(loc=70, scale=12, size=50)

moe = margin_of_error(sample_data, confidence=0.95)
mean = np.mean(sample_data)

print(f"Sample Mean: {mean:.2f}")
print(f"Margin of Error (95% CI): ±{moe:.2f}")
print(f"Confidence Interval: ({mean - moe:.2f}, {mean + moe:.2f})")
# Out:
# Sample Mean: 71.69
# Margin of Error (95% CI): ±3.88
# Confidence Interval: (67.81, 75.56)

# %% [markdown]
# Q11.Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Observed data
heads = 7
tails = 3
trials = heads + tails

# Prior belief: Uniform distribution (Beta(1,1) = no prior preference)
alpha_prior = 1
beta_prior = 1

# Posterior distribution parameters (Bayes update for Beta prior and Binomial likelihood)
alpha_post = alpha_prior + heads
beta_post = beta_prior + tails

# Plot prior and posterior distributions
x = np.linspace(0, 1, 1000)
prior_pdf = beta.pdf(x, alpha_prior, beta_prior)
posterior_pdf = beta.pdf(x, alpha_post, beta_post)

plt.figure(figsize=(10, 5))
plt.plot(x, prior_pdf, label='Prior: Beta(1,1)', linestyle='--')
plt.plot(x, posterior_pdf, label=f'Posterior: Beta({alpha_post},{beta_post})', color='red')
plt.title('Bayesian Inference: Coin Bias Estimation')
plt.xlabel('Probability of Heads')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Q12. Perform a Chi-square test for independence between two categorical variables in Python?

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Create a contingency table
data = np.array([[30, 10],   # Male
                 [20, 20]])  # Female

# Step 2: Perform Chi-Square Test
chi2, p, dof, expected = chi2_contingency(data)

# Step 3: Print results
print("Chi-square Statistic:", round(chi2, 4))
print("Degrees of Freedom:", dof)
print("P-value:", round(p, 4))
print("\nExpected Frequencies:")
print(pd.DataFrame(expected, columns=["Likes", "Dislikes"], index=["Male", "Female"]))

# Step 4: Interpretation
alpha = 0.05
if p < alpha:
    print("\n🔍 Result: Reject the null hypothesis (variables are dependent)")
else:
    print("\n✅ Result: Fail to reject the null hypothesis (variables are independent)")
# Out:
# Chi-square Statistic: 4.32
# Degrees of Freedom: 1
# P-value: 0.0377
#
# Expected Frequencies:
#         Likes  Dislikes
# Male     25.0      15.0
# Female   25.0      15.0
#
# 🔍 Result: Reject the null hypothesis (variables are dependent)

# %% [markdown]
# Q13.Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data?

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Define observed data (Contingency Table)
# Example: Gender vs Product Preference
# Rows: Gender (Male, Female)
# Columns: Preference (Like, Dislike)
observed = np.array([[30, 10],   # Male
                     [20, 20]])  # Female

# Step 2: Perform Chi-Square test to get expected frequencies
chi2, p, dof, expected = chi2_contingency(observed)

# Step 3: Display expected frequencies
expected_df = pd.DataFrame(expected,
                           columns=["Likes", "Dislikes"],
                           index=["Male", "Female"])

print("📊 Observed Frequencies:\n", pd.DataFrame(observed, columns=["Likes", "Dislikes"], index=["Male", "Female"]))
print("\n📈 Expected Frequencies (Under Independence Assumption):\n", expected_df.round(2))
# Out:
# 📊 Observed Frequencies:
#          Likes  Dislikes
# Male       30        10
# Female     20        20
#
# 📈 Expected Frequencies (Under Independence Assumption):
#          Likes  Dislikes
# Male     25.0      15.0
# Female   25.0      15.0

# %% [markdown]
# Q14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
from scipy.stats import chisquare

# Step 1: Define observed and expected frequencies
observed = [8, 9, 10, 12, 11, 10]
expected = [10, 10, 10, 10, 10, 10]

# Step 2: Perform the Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Step 3: Output results
print("Chi-square Statistic:", round(chi2_stat, 4))
print("P-value:", round(p_value, 4))

# Step 4: Interpretation
alpha = 0.05
if p_value < alpha:
    print("❌ Reject the null hypothesis — observed distribution differs from expected.")
else:
    print("✅ Fail to reject the null hypothesis — observed distribution fits expected.")
# Out:
# Chi-square Statistic: 1.0
# P-value: 0.9626
# ✅ Fail to reject the null hypothesis — observed distribution fits expected.
